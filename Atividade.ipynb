# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavoalves14/ALGESTDADOS20261/blob/main/Atividade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = 0.3

if numero > 0:
     print("O número é positivo!")

print("Fim do programa")
# Está linha sempre executa
# Out:
# O número é positivo!
# Fim do programa

# %%
idade = int(input("Digite sua idade: "))

if idade >= 18:
    print("Você é maior de idade.")
    print("Pode dirigir e votar." )
else:
    print("Você é menor de idade.")
    print("VocÊ é menor de idade.")
print("verificação concluida!")
# Out:
# Digite sua idade: 11
# Você é menor de idade.
# VocÊ é menor de idade.
# verificação concluida!

# %%
nota = float(input("Digite sua nota (0 a 10): "))
if nota > 9.0:
  conceito = "A"
  status = "Excelente!"
elif nota >= 7.0:
 conceito = "B"
 status = "Aprovado"
elif nota >= 5.0:
 conceito = "D"
 status = "Recuperação"
else:
  conceito = "D"
  status = "Reprovado"
print(f"Conceito: {conceito} - {status}")
# Out:
# Digite sua nota (0 a 10): 7
# Conceito: B - Aprovado

# %%
idade = 69
if idade >=18:
  print("Maior de idade")

  if idade >=60:
     print("Idoso")
  else:
     print("Adulto")
else:
    print("Menor de idade")
# Out:
# Maior de idade
# Idoso

# %%
dia = int(input("Número do dia (1-7): "))
match dia:
  case 1:
    print("Segunda-feira")
  case 2:
    print("Terça-feira")
  case 3:
    print("Quarta-feira")
  case 4:
    print("Quinta-feira")
  case 5:
    print("Sexta-feira")
  case 6 | 7:
    print("Final de semana")
# Out:
# Número do dia (1-7): 6
# Final de semana

# %%
# Leia um número de 1 a 7 e exiba o nome do dia correspondente (1 = Segunda, ..., 7 = Domingo). Para qualquer outro número, exiba "Número inválido".
idade = int(input("Digite sua idade: "))

if idade >= 18:
   print("Maior de idade")
else:
   print("Menor de idade")
# Out:
# Digite sua idade: 15
# Menor de idade

# %%
# leia a temperatura. Classifique usando elif: abaixo de 0 → "Congelante", 0 a 15 → "Frio", 16 a 25 → "Agradável", 26 a 35 → "Quente", acima de 35 → "Muito quente".

temperatura = float(input("Digite a temperatura atual (C°): "))
if temperatura > 30:
    print("Está quente hoje")
else:
    print("Está frio hoje")
# Out:
# Digite a temperatura atual (C°): 23
# Está frio hoje

# %%
# Defina um saldo fixo (ex: 100.0). Peça ao usuário um valor para saque. Se o valor for menor ou igual ao saldo, exiba "Saque realizado!", caso contrário, "Saldo insuficiente."
saldo = 1000
saque = float(input("Digite o valor do saque: "))
if saque <= saldo:
    print("Saque realizado!")
else:
    print("Saldo insuficiente")
# Out:
# Digite o valor do saque: 1200
# Saldo insuficiente

# %%
# Leia a nota de um aluno (0 a 10). Se a nota for maior ou igual a 5, exiba "Aprovado". Senão, exiba "Reprovado".
nota = float(input("Digite a nota do aluno: "))
if nota >= 5:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a nota do aluno: 7
# Aprovado

# %%
# Peça um número ao usuário. Exiba se o número é zero ou diferente de zero usando if/else.
numero = int(input("Digite um número: "))
if numero%2 == 0:
    print("Número par!")
else:
    print("Número ímpar!")
# Out:
# Digite um número: 8
# Número par!

# %%
# Peça um número ao usuário. Sem usar == 0, use o próprio valor como condição no if para exibir "O número é falsy (zero)" ou "O número é truthy (diferente de zero)".
numero = bool(int(input("Digite um número: ")))
if numero is True:
    print("Diferente de zero ")
else:
    print("O número é falsy (zero)")
# Out:
# Digite um número: 0
# O número é falsy (zero)

# %%
# Peça ao usuário para digitar a cor do semáforo ("verde" ou outra cor). Se for "verde", exiba "Pode avançar!", caso contrário, "Pare!".
cor = input("Digite a cor do semáforo:")

if cor == "VERDE" or "verde" or "Verde":
    print("Podeavançar!")
else:
    print("Pare!")
# Out:
# Digite a cor do semáforo:vermelho
# Podeavançar!

# %%
# 1 Leia a nota de um aluno. Classifique usando elif: nota ≥ 9 → "A — Excelente", ≥ 7 → "B — Aprovado", ≥ 5 → "C — Recuperação", abaixo → "D — Reprovado".
nota = float(input("Digite a nota do aluno: "))
if nota >= 9:
    print("A - Excelente")
elif nota >= 7:
    print("B - Aprovado")
elif nota >= 5:
    print("C - Recuperação")
elif nota < 5:
    print("D - Reprovado")
# Out:
# Digite a nota do aluno: 8
# B - Aprovado

# %%
# 2 Leia um número de 1 a 7 e exiba o nome do dia correspondente (1 = Segunda, ..., 7 = Domingo). Para qualquer outro número, exiba "Número inválido".
dia = int(input("Dia da semana:"))
match dia:
    case 1 :print("Domingo")
    case 2 :print("Segunda-Feira")
    case 3 :print("Terça feira")
    case 4 :print("Quarta-Feira")
    case 5 :print("Quinta-Feira")
    case 6 :print("Sexta-Feira")
    case 7 :print("Sabado")
    case _:print("Inexistente")
# Out:
# Dia da semana:2
# Segunda-Feira

# %%
# 3 Leia uma nota. Valide se está entre 0 e 10 usando encadeamento de comparações (0 <= nota <= 10). Se inválida, exiba "Nota inválida!". Se válida, exiba "Nota registrada: [nota]".
nota = float(input("Digite uma nota: "))
if 0 <= nota <= 10:
    print(f"Nota registrada {nota}")
    print("Nota válida")
else:
    print("Nota inválida!")
# Out:
# Digite uma nota: -2
# Nota inválida!

# %%
# 4 Leia a idade. Classifique: menor de 12 → "Criança", 12 a 17 → "Adolescente", 18 a 59 → "Adulto", 60 ou mais → "Idoso". Valide que a idade não é negativa.
idade = int(input("Digite sua idade: "))
if idade < 0 or idade > 120:
    print("Idade inválida")
elif 0 < idade < 12:
    print("Criança")
    print("Idade valida")
elif 12 <= idade < 18:
    print("Adolescente")
    print("Idade valida")
elif 18 <= idade < 60:
    print("Adulto")
    print("Idade valida")
elif 60 <= idade:
    print("Idoso")
    print("Idade valida")

# %%
# 5 Exiba um menu com 3 opções (ex: 1-Água R$2, 2-Suco R$6, 3-Café R$4). Leia a escolha. Valide com not (1 <= item <= 3). Se inválido, exiba erro; se válido, exiba o item e o preço.
item = int(input("Menu/ n1-Água R$2/ n2-Suco R$6/ n3-Café R$4/Escolha um item: "))
if not (1 <=  item <= 3):
    print("Erro")
else:
    match item:
        case 1: print("Você adiquiriu uma Àgua")
        case 2: print("Você adiquiriu um Suco")
        case 3: print("Você adiquiriu um Café")

# %%
# 6 Leia a temperatura. Classifique usando elif: abaixo de 0 → "Congelante", 0 a 15 → "Frio", 16 a 25 → "Agradável", 26 a 35 → "Quente", acima de 35 → "Muito quente".

# %%
# 7 Leia dois números e um operador (+, -, *, /). Use elif para realizar a operação correta. Valide a divisão por zero. Para operador inválido, exiba "Operador desconhecido".

# %%
# 8 Defina um usuário e senha corretos no código. Leia usuário e senha. Somente se ambos estiverem corretos (usando and), exiba "Login efetuado!". Caso contrário, "Usuário ou senha incorretos."

# %%
# 9
